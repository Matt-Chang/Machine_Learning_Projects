# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'f66a8388-f68c-4ab0-8f98-ac237e408dfc',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data

# %%
import pandas as pd

#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#This normalizes the data and makes it all pretty in a dataframe
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#       id             name symbol                  slug  num_market_pairs  \
# 0      1          Bitcoin    BTC               bitcoin              9528
# 1   1027         Ethereum    ETH              ethereum              5745
# 2    825           Tether   USDT                tether             34593
# 3   3408         USD Coin   USDC              usd-coin              4379
# 4   1839              BNB    BNB                   bnb               947
# 5   2010          Cardano    ADA               cardano               454
# 6   4687      Binance USD   BUSD           binance-usd              3834
# 7     52              XRP    XRP                   xrp               737
# 8   5426           Solana    SOL                solana               327
# 9     74         Dogecoin   DOGE              dogecoin               484
# 10  6636         Polkadot    DOT          polkadot-new               351
# 11  3717  Wrapped Bitcoin   WBTC       wrapped-bitcoin               450
# ...

# %%
def api_runner():
        global df
        from requests import Request, Session
        from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
        import json

        url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
        #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
        parameters = {
          'start':'1',
          'limit':'15',
          'convert':'USD'
        }
        headers = {
          'Accepts': 'application/json',
          'X-CMC_PRO_API_KEY': 'f66a8388-f68c-4ab0-8f98-ac237e408dfc',
        }

        session = Session()
        session.headers.update(headers)

        try:
          response = session.get(url, params=parameters)
          data = json.loads(response.text)
          #print(data)
        except (ConnectionError, Timeout, TooManyRedirects) as e:
          print(e)

        #NOTE:
        # I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
        # Into the Anaconda Prompt to change this to allow to pull data

        # If that didn't work try using the local host URL as shown in the video
        type(data)
        import pandas as pd


        #This allows you to see all the columns, not just like 15
        pd.set_option('display.max_columns', None)
        #pd.set_option('display.max_rows', None)
        #This normalizes the data and makes it all pretty in a dataframe

        df2 = pd.json_normalize(data['data'])
        df2['timestamp']= pd.to_datetime('now')
        df = df.append(df2)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4172/314683833.py in <module>
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df
# Out:
#       id             name symbol                  slug  num_market_pairs  \
# 0      1          Bitcoin    BTC               bitcoin              9528
# 1   1027         Ethereum    ETH              ethereum              5745
# 2    825           Tether   USDT                tether             34593
# 3   3408         USD Coin   USDC              usd-coin              4379
# 4   1839              BNB    BNB                   bnb               947
# 5   2010          Cardano    ADA               cardano               454
# 6   4687      Binance USD   BUSD           binance-usd              3834
# 7     52              XRP    XRP                   xrp               737
# 8   5426           Solana    SOL                solana               327
# 9     74         Dogecoin   DOGE              dogecoin               484
# 10  6636         Polkadot    DOT          polkadot-new               351
# 11  3717  Wrapped Bitcoin   WBTC       wrapped-bitcoin               450
# ...

# %%
def api_runner():
        global df
        from requests import Request, Session
        from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
        import json

        url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
        #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
        parameters = {
          'start':'1',
          'limit':'15',
          'convert':'USD'
        }
        headers = {
          'Accepts': 'application/json',
          'X-CMC_PRO_API_KEY': 'f66a8388-f68c-4ab0-8f98-ac237e408dfc',
        }

        session = Session()
        session.headers.update(headers)

        try:
          response = session.get(url, params=parameters)
          data = json.loads(response.text)
          #print(data)
        except (ConnectionError, Timeout, TooManyRedirects) as e:
          print(e)

        #NOTE:
        # I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
        # Into the Anaconda Prompt to change this to allow to pull data

        # If that didn't work try using the local host URL as shown in the video
        type(data)
        import pandas as pd


        #This allows you to see all the columns, not just like 15
        pd.set_option('display.max_columns', None)
        #pd.set_option('display.max_rows', None)
        #This normalizes the data and makes it all pretty in a dataframe

        df = pd.json_normalize(data['data'])
        df['timestamp']= pd.to_datetime('now')
        df = df.append(df2)
        if not os.path.isfile(r'C:\Users\user\Desktop\DataAnalyst\Projects\Python\API Project\API1.csv'):
                             df.to_csv(r'C:\Users\user\Desktop\DataAnalyst\Projects\Python\API Project\API1.csv',header='column_names')
        else: 
          df.to_csv(r'C:\Users\user\Desktop\DataAnalyst\Projects\Python\API Project\API1.csv',mode='a',header=False)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4172/314683833.py in <module>
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r'C:\Users\user\Desktop\DataAnalyst\Projects\Python\API Project\API1.csv')
df72
# Out:
#     Unnamed: 0    id             name symbol                  slug  \
# 0            0     1          Bitcoin    BTC               bitcoin
# 1            1  1027         Ethereum    ETH              ethereum
# 2            2   825           Tether   USDT                tether
# 3            3  3408         USD Coin   USDC              usd-coin
# 4            4  1839              BNB    BNB                   bnb
# 5            5  2010          Cardano    ADA               cardano
# 6            6  4687      Binance USD   BUSD           binance-usd
# 7            7    52              XRP    XRP                   xrp
# 8            8  5426           Solana    SOL                solana
# 9            9    74         Dogecoin   DOGE              dogecoin
# 10          10  6636         Polkadot    DOT          polkadot-new
# 11          11  3717  Wrapped Bitcoin   WBTC       wrapped-bitcoin
# 12          12  1958             TRON    TRX                  tron
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
df
# Out:
#       id             name symbol                  slug  num_market_pairs  \
# 0      1          Bitcoin    BTC               bitcoin              9528
# 1   1027         Ethereum    ETH              ethereum              5745
# 2    825           Tether   USDT                tether             34593
# 3   3408         USD Coin   USDC              usd-coin              4379
# 4   1839              BNB    BNB                   bnb               947
# 5   2010          Cardano    ADA               cardano               454
# 6   4687      Binance USD   BUSD           binance-usd              3834
# 7     52              XRP    XRP                   xrp               737
# 8   5426           Solana    SOL                solana               327
# 9     74         Dogecoin   DOGE              dogecoin               484
# 10  6636         Polkadot    DOT          polkadot-new               351
# 11  3717  Wrapped Bitcoin   WBTC       wrapped-bitcoin               450
# ...

# %%
df3 = df.groupby('name',sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()

# %%
df3
# Out:
#                  quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                               0.1924                       -2.3444
# Ethereum                              0.1519                       -7.9823
# Tether                               -0.0080                       -0.0108
# USD Coin                              0.0061                        0.0056
# BNB                                  -0.0187                       -5.9107
# Cardano                               0.2795                       -3.6517
# Binance USD                          -0.0959                       -0.0428
# XRP                                  -0.1983                       -5.6289
# Solana                               -0.0482                       -8.4019
# Dogecoin                             -0.0194                       -7.0212
# Polkadot                              0.2321                       -7.0763
# ...

# %%
df4 =df3.stack()

# %%
df4
# Out:
# name
# Bitcoin          quote.USD.percent_change_1h      0.1924
#                  quote.USD.percent_change_24h    -2.3444
#                  quote.USD.percent_change_7d     -4.5189
#                  quote.USD.percent_change_30d    -1.9453
#                  quote.USD.percent_change_60d   -28.9944
#                  quote.USD.percent_change_90d   -24.5544
# Ethereum         quote.USD.percent_change_1h      0.1519
#                  quote.USD.percent_change_24h    -7.9823
#                  quote.USD.percent_change_7d    -14.7500
#                  quote.USD.percent_change_30d   -21.8124
#                  quote.USD.percent_change_60d   -49.3091
#                  quote.USD.percent_change_90d   -38.7516
# Tether           quote.USD.percent_change_1h     -0.0080
#                  quote.USD.percent_change_24h    -0.0108
#                  quote.USD.percent_change_7d     -0.0234
#                  quote.USD.percent_change_30d     0.1699
# ...

# %%
df5 = df4.to_frame(name='value')

# %%
df5
# Out:
#                                                 value
# name
# Bitcoin         quote.USD.percent_change_1h    0.1924
#                 quote.USD.percent_change_24h  -2.3444
#                 quote.USD.percent_change_7d   -4.5189
#                 quote.USD.percent_change_30d  -1.9453
#                 quote.USD.percent_change_60d -28.9944
#                 quote.USD.percent_change_90d -24.5544
# Ethereum        quote.USD.percent_change_1h    0.1519
#                 quote.USD.percent_change_24h  -7.9823
#                 quote.USD.percent_change_7d  -14.7500
#                 quote.USD.percent_change_30d -21.8124
#                 quote.USD.percent_change_60d -49.3091
#                 quote.USD.percent_change_90d -38.7516
# Tether          quote.USD.percent_change_1h   -0.0080
#                 quote.USD.percent_change_24h  -0.0108
#                 quote.USD.percent_change_7d   -0.0234
#                 quote.USD.percent_change_30d   0.1699
# ...

# %%
df5.count()
# Out:
# value    90
# dtype: int64

# %%
df6 = df5.reset_index()
df6
# Out:
#                name                       level_1    value
# 0           Bitcoin   quote.USD.percent_change_1h   0.1924
# 1           Bitcoin  quote.USD.percent_change_24h  -2.3444
# 2           Bitcoin   quote.USD.percent_change_7d  -4.5189
# 3           Bitcoin  quote.USD.percent_change_30d  -1.9453
# 4           Bitcoin  quote.USD.percent_change_60d -28.9944
# 5           Bitcoin  quote.USD.percent_change_90d -24.5544
# 6          Ethereum   quote.USD.percent_change_1h   0.1519
# 7          Ethereum  quote.USD.percent_change_24h  -7.9823
# 8          Ethereum   quote.USD.percent_change_7d -14.7500
# 9          Ethereum  quote.USD.percent_change_30d -21.8124
# 10         Ethereum  quote.USD.percent_change_60d -49.3091
# 11         Ethereum  quote.USD.percent_change_90d -38.7516
# 12           Tether   quote.USD.percent_change_1h  -0.0080
# 13           Tether  quote.USD.percent_change_24h  -0.0108
# 14           Tether   quote.USD.percent_change_7d  -0.0234
# ...

# %% [markdown]
# ######

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#                name                percent_change    value
# 0           Bitcoin   quote.USD.percent_change_1h   0.1924
# 1           Bitcoin  quote.USD.percent_change_24h  -2.3444
# 2           Bitcoin   quote.USD.percent_change_7d  -4.5189
# 3           Bitcoin  quote.USD.percent_change_30d  -1.9453
# 4           Bitcoin  quote.USD.percent_change_60d -28.9944
# 5           Bitcoin  quote.USD.percent_change_90d -24.5544
# 6          Ethereum   quote.USD.percent_change_1h   0.1519
# 7          Ethereum  quote.USD.percent_change_24h  -7.9823
# 8          Ethereum   quote.USD.percent_change_7d -14.7500
# 9          Ethereum  quote.USD.percent_change_30d -21.8124
# 10         Ethereum  quote.USD.percent_change_60d -49.3091
# 11         Ethereum  quote.USD.percent_change_90d -38.7516
# 12           Tether   quote.USD.percent_change_1h  -0.0080
# 13           Tether  quote.USD.percent_change_24h  -0.0108
# 14           Tether   quote.USD.percent_change_7d  -0.0234
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#                name percent_change    value
# 0           Bitcoin             1h   0.1924
# 1           Bitcoin            24h  -2.3444
# 2           Bitcoin             7d  -4.5189
# 3           Bitcoin            30d  -1.9453
# 4           Bitcoin            60d -28.9944
# 5           Bitcoin            90d -24.5544
# 6          Ethereum             1h   0.1519
# 7          Ethereum            24h  -7.9823
# 8          Ethereum             7d -14.7500
# 9          Ethereum            30d -21.8124
# 10         Ethereum            60d -49.3091
# 11         Ethereum            90d -38.7516
# 12           Tether             1h  -0.0080
# 13           Tether            24h  -0.0108
# 14           Tether             7d  -0.0234
# 15           Tether            30d   0.1699
# 16           Tether            60d  -0.1140
# 17           Tether            90d  -0.1136
# 18         USD Coin             1h   0.0061
# 19         USD Coin            24h   0.0056
# ...

# %%
sns.catplot(x='percent_change', y='value', hue='name', data=df7, kind='point')

# %%
df10 = df[['name', 'quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin       28492.6011 2022-06-12 00:40:04.453259
# 0  Bitcoin       28495.6203 2022-06-12 00:16:08.336143
